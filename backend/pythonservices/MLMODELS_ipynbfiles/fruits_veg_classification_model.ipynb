# %% [markdown]
# # Importing necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf


from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# Load images from data set

# %%
data_train_path = '../Fruits_Vegetables/train'
data_test_path = "../Fruits_Vegetables/test"
data_validate_path = "../Fruits_Vegetables/validation"

# %% [markdown]
# setting output path and model name

# %%
model_output_path = "../MLModels/"
model_name = "fruits_veg_model.keras"

# %% [markdown]
# Initializing image width and height

# %%
image_width = 180
image_height = 180

# %% [markdown]
# # Loading Data set from Directory Path

# %% [markdown]
# - reads images from folders
# - automatically assigns labels based on folder names
# - Resizes images to initialized image width and height
# - creates batches of size 32

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle = True,
    image_size = (image_width, image_height),
    batch_size = 32,
    validation_split =False
    )
# Out:
# Found 3115 files belonging to 36 classes.

# %%
data_category = data_train.class_names

# %% [markdown]
# Setting up validation data

# %%
data_validatation = tf.keras.utils.image_dataset_from_directory(
    data_validate_path,
    shuffle = True,
    image_size = (image_width, image_height),
    batch_size = 32,
    validation_split =False
    )
# Out:
# Found 351 files belonging to 36 classes.

# %% [markdown]
# setting up test data

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    shuffle = True,
    image_size = (image_width, image_height),
    batch_size = 32,
    validation_split =False
    )
# Out:
# Found 359 files belonging to 36 classes.

# %% [markdown]
# Plotting images from data set

# %%
plt.figure(figsize= (10,10))
for image,labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_category[labels[i]])
        plt.axis('off')

# %% [markdown]
# ## Building a CNN Model

# %% [markdown]
# - Conv layers extract image features
# - polling layers reduce size
# - flatten converts to vector
# - dense layers perform classification
# - Dropout prevents overfitting

# %%
model = Sequential([
    layers.Rescaling(1/255),
    layers.Conv2D(16,3,padding='same',activation= 'relu'),
    layers.MaxPool2D(),
    layers.Conv2D(32,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(units=len(data_category))
    ])

# %% [markdown]
# # Compiling the Model

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
    )
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# - model.fit() → this is the training step where the CNN actually learns patterns from your training images. Without this, your model is just an untrained network — it cannot classify anything.
#
# - data_train → your training images are passed here so the model can learn features of fruits/vegetables.
#
# - validation_data=data_validatation → used to evaluate model performance after each epoch. Helps detect overfitting.
#
# - epochs=epochs_size → number of full passes over your training dataset.
#
# - More epochs → better learning, but too many → overfitting.
#
# - batch_size=32 → number of images processed together in one step. Helps optimize memory usage.
#
# - verbose=1 → shows the progress of training in the console.
#
# - history → stores training metrics (accuracy & loss) for plotting and analysis.

# %%
epochs_size = 25
history = model.fit(
    data_train,
    validation_data=data_validatation,
    epochs=epochs_size,
    batch_size=32,
    verbose=1
    )
# Out:
# Epoch 1/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.0864 - loss: 3.5220 - val_accuracy: 0.2507 - val_loss: 2.6123
# Epoch 2/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 19s 198ms/step - accuracy: 0.2783 - loss: 2.5271 - val_accuracy: 0.4843 - val_loss: 1.7370
# Epoch 3/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 17s 160ms/step - accuracy: 0.3868 - loss: 2.1041 - val_accuracy: 0.6040 - val_loss: 1.4757
# Epoch 4/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 140ms/step - accuracy: 0.5069 - loss: 1.6845 - val_accuracy: 0.7863 - val_loss: 0.8332
# Epoch 5/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 141ms/step - accuracy: 0.6469 - loss: 1.2230 - val_accuracy: 0.8462 - val_loss: 0.5954
# Epoch 6/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 140ms/step - accuracy: 0.7872 - loss: 0.7386 - val_accuracy: 0.8860 - val_loss: 0.4477
# Epoch 7/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 138ms/step - accuracy: 0.8555 - loss: 0.5270 - val_accuracy: 0.9202 - val_loss: 0.3224
# Epoch 8/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 137ms/step - accuracy: 0.8995 - loss: 0.3581 - val_accuracy: 0.9316 - val_loss: 0.3461
# Epoch 9/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9416 - loss: 0.2324 - val_accuracy: 0.9402 - val_loss: 0.2965
# Epoch 10/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9570 - loss: 0.1831 - val_accuracy: 0.9487 - val_loss: 0.3318
# Epoch 11/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 139ms/step - accuracy: 0.9679 - loss: 0.1431 - val_accuracy: 0.9544 - val_loss: 0.3177
# Epoch 12/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 138ms/step - accuracy: 0.9708 - loss: 0.1436 - val_accuracy: 0.9487 - val_loss: 0.3093
# Epoch 13/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 137ms/step - accuracy: 0.9769 - loss: 0.1061 - val_accuracy: 0.9487 - val_loss: 0.2847
# Epoch 14/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 144ms/step - accuracy: 0.9804 - loss: 0.1104 - val_accuracy: 0.9601 - val_loss: 0.2151
# Epoch 15/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 137ms/step - accuracy: 0.9791 - loss: 0.1031 - val_accuracy: 0.9544 - val_loss: 0.2873
# Epoch 16/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 143ms/step - accuracy: 0.9817 - loss: 0.0877 - val_accuracy: 0.9544 - val_loss: 0.3275
# Epoch 17/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 140ms/step - accuracy: 0.9820 - loss: 0.0894 - val_accuracy: 0.9516 - val_loss: 0.2859
# Epoch 18/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 138ms/step - accuracy: 0.9862 - loss: 0.0858 - val_accuracy: 0.9630 - val_loss: 0.3495
# Epoch 19/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 138ms/step - accuracy: 0.9856 - loss: 0.0635 - val_accuracy: 0.9630 - val_loss: 0.3295
# Epoch 20/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 145ms/step - accuracy: 0.9785 - loss: 0.0876 - val_accuracy: 0.9459 - val_loss: 0.3653
# Epoch 21/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 142ms/step - accuracy: 0.9753 - loss: 0.1084 - val_accuracy: 0.9544 - val_loss: 0.3612
# Epoch 22/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 140ms/step - accuracy: 0.9833 - loss: 0.0742 - val_accuracy: 0.9573 - val_loss: 0.2789
# Epoch 23/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 146ms/step - accuracy: 0.9856 - loss: 0.0663 - val_accuracy: 0.9630 - val_loss: 0.2417
# Epoch 24/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 144ms/step - accuracy: 0.9823 - loss: 0.0772 - val_accuracy: 0.9544 - val_loss: 0.3242
# Epoch 25/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 14s 142ms/step - accuracy: 0.9820 - loss: 0.0717 - val_accuracy: 0.9630 - val_loss: 0.2559

# %% [markdown]
# Plotting Accuracy and Val Accuracy

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label='TrainingAccuracy')
plt.plot(epochs_range,history.history['accuracy'],label='ValidationAccuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label='Trainingloss')
plt.plot(epochs_range,history.history['val_loss'],label='Validation loss')
plt.title('Loss')
plt.show()

# %% [markdown]
# ## saving the model

# %%
model.save(model_output_path+model_name)

# %% [markdown]
# ## Predicting a New Image

# %%
image = "hello.jpg"
image = tf.keras.utils.load_img(image,target_size=(image_height,image_width))
image_arr = tf.keras.utils.array_to_img(image)
image_bat = tf.expand_dims(image_arr,0)

# %%
predict = model.predict(image_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(
    data_category[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is carrot with accuracy of 85.95
