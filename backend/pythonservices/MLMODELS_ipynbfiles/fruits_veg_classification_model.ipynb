# %% [markdown]
# # Importing necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf


from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# Load images from data set

# %%
data_train_path = '../Fruits_Vegetables/train'
data_test_path = "../Fruits_Vegetables/test"
data_validate_path = "../Fruits_Vegetables/validation"

# %% [markdown]
# setting output path and model name

# %%
model_output_path = "../MLModels/"
model_name = "fruits_veg_model.keras"

# %% [markdown]
# Initializing image width and height

# %%
image_width = 180
image_height = 180

# %% [markdown]
# # Loading Data set from Directory Path

# %% [markdown]
# - reads images from folders
# - automatically assigns labels based on folder names
# - Resizes images to initialized image width and height
# - creates batches of size 32

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle = True,
    image_size = (image_width, image_height),
    batch_size = 32,
    validation_split =False
    )
# Out:
# Found 4377 files belonging to 98 classes.

# %%
data_category = data_train.class_names

# %% [markdown]
# Setting up validation data

# %%
data_validatation = tf.keras.utils.image_dataset_from_directory(
    data_validate_path,
    shuffle = True,
    image_size = (image_width, image_height),
    batch_size = 32,
    validation_split =False
    )
# Out:
# Found 351 files belonging to 36 classes.

# %% [markdown]
# setting up test data

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    shuffle = True,
    image_size = (image_width, image_height),
    batch_size = 32,
    validation_split =False
    )
# Out:
# Found 359 files belonging to 36 classes.

# %% [markdown]
# Plotting images from data set

# %%
plt.figure(figsize= (10,10))
for image,labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_category[labels[i]])
        plt.axis('off')

# %% [markdown]
# ## Building a CNN Model

# %% [markdown]
# - Conv layers extract image features
# - polling layers reduce size
# - flatten converts to vector
# - dense layers perform classification
# - Dropout prevents overfitting

# %%
model = Sequential([
    layers.Rescaling(1/255),
    layers.Conv2D(16,3,padding='same',activation= 'relu'),
    layers.MaxPool2D(),
    layers.Conv2D(32,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(units=len(data_category))
    ])

# %% [markdown]
# # Compiling the Model

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
    )
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# - model.fit() → this is the training step where the CNN actually learns patterns from your training images. Without this, your model is just an untrained network — it cannot classify anything.
#
# - data_train → your training images are passed here so the model can learn features of fruits/vegetables.
#
# - validation_data=data_validatation → used to evaluate model performance after each epoch. Helps detect overfitting.
#
# - epochs=epochs_size → number of full passes over your training dataset.
#
# - More epochs → better learning, but too many → overfitting.
#
# - batch_size=32 → number of images processed together in one step. Helps optimize memory usage.
#
# - verbose=1 → shows the progress of training in the console.
#
# - history → stores training metrics (accuracy & loss) for plotting and analysis.

# %%
epochs_size = 25
history = model.fit(
    data_train,
    validation_data=data_validatation,
    epochs=epochs_size,
    batch_size=32,
    verbose=1
    )
# Out:
# Epoch 1/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 20s 135ms/step - accuracy: 0.0786 - loss: 4.1272 - val_accuracy: 0.0000e+00 - val_loss: 6.7079
# Epoch 2/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 18s 131ms/step - accuracy: 0.2570 - loss: 2.8618 - val_accuracy: 0.0028 - val_loss: 9.7640
# Epoch 3/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 18s 128ms/step - accuracy: 0.4773 - loss: 1.9347 - val_accuracy: 0.0028 - val_loss: 12.2382
# Epoch 4/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 112ms/step - accuracy: 0.6623 - loss: 1.1969 - val_accuracy: 0.0057 - val_loss: 13.7348
# Epoch 5/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - accuracy: 0.8026 - loss: 0.7021 - val_accuracy: 0.0000e+00 - val_loss: 16.4695
# Epoch 6/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 119ms/step - accuracy: 0.8778 - loss: 0.4442 - val_accuracy: 0.0000e+00 - val_loss: 21.0665
# Epoch 7/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 114ms/step - accuracy: 0.9203 - loss: 0.2942 - val_accuracy: 0.0000e+00 - val_loss: 21.6552
# Epoch 8/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 112ms/step - accuracy: 0.9390 - loss: 0.2294 - val_accuracy: 0.0000e+00 - val_loss: 20.6005
# Epoch 9/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 108ms/step - accuracy: 0.9593 - loss: 0.1734 - val_accuracy: 0.0000e+00 - val_loss: 23.8063
# Epoch 10/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 108ms/step - accuracy: 0.9504 - loss: 0.2119 - val_accuracy: 0.0000e+00 - val_loss: 23.8445
# Epoch 11/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 108ms/step - accuracy: 0.9662 - loss: 0.1521 - val_accuracy: 0.0000e+00 - val_loss: 24.8720
# Epoch 12/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 108ms/step - accuracy: 0.9726 - loss: 0.1229 - val_accuracy: 0.0000e+00 - val_loss: 24.5464
# Epoch 13/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 109ms/step - accuracy: 0.9756 - loss: 0.1312 - val_accuracy: 0.0000e+00 - val_loss: 26.3953
# Epoch 14/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 112ms/step - accuracy: 0.9728 - loss: 0.1319 - val_accuracy: 0.0000e+00 - val_loss: 25.9002
# Epoch 15/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 111ms/step - accuracy: 0.9703 - loss: 0.1257 - val_accuracy: 0.0000e+00 - val_loss: 23.8615
# Epoch 16/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 110ms/step - accuracy: 0.9758 - loss: 0.1086 - val_accuracy: 0.0000e+00 - val_loss: 26.0681
# Epoch 17/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 109ms/step - accuracy: 0.9769 - loss: 0.1025 - val_accuracy: 0.0000e+00 - val_loss: 25.0156
# Epoch 18/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 108ms/step - accuracy: 0.9758 - loss: 0.0984 - val_accuracy: 0.0000e+00 - val_loss: 28.6235
# Epoch 19/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 109ms/step - accuracy: 0.9767 - loss: 0.0980 - val_accuracy: 0.0000e+00 - val_loss: 25.5905
# Epoch 20/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 111ms/step - accuracy: 0.9762 - loss: 0.1015 - val_accuracy: 0.0000e+00 - val_loss: 25.4780
# Epoch 21/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 109ms/step - accuracy: 0.9826 - loss: 0.0821 - val_accuracy: 0.0000e+00 - val_loss: 27.2786
# Epoch 22/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 109ms/step - accuracy: 0.9783 - loss: 0.0929 - val_accuracy: 0.0000e+00 - val_loss: 28.7169
# Epoch 23/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 110ms/step - accuracy: 0.9804 - loss: 0.1070 - val_accuracy: 0.0000e+00 - val_loss: 28.4522
# Epoch 24/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 113ms/step - accuracy: 0.9851 - loss: 0.0673 - val_accuracy: 0.0000e+00 - val_loss: 29.1158
# Epoch 25/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 111ms/step - accuracy: 0.9815 - loss: 0.0747 - val_accuracy: 0.0000e+00 - val_loss: 28.0146

# %% [markdown]
# Plotting Accuracy and Val Accuracy

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label='TrainingAccuracy')
plt.plot(epochs_range,history.history['accuracy'],label='ValidationAccuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label='Trainingloss')
plt.plot(epochs_range,history.history['val_loss'],label='Validation loss')
plt.title('Loss')
plt.show()

# %% [markdown]
# ## saving the model

# %%
model.save(model_output_path+model_name)

# %% [markdown]
# ## Predicting a New Image

# %%
image = "hello.jpg"
image = tf.keras.utils.load_img(image,target_size=(image_height,image_width))
image_arr = tf.keras.utils.array_to_img(image)
image_bat = tf.expand_dims(image_arr,0)

# %%
predict = model.predict(image_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(
    data_category[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is beetroot with accuracy of 43.09
