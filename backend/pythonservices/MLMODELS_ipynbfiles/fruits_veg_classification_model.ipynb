# %% [markdown]
# # Importing necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf


from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# Load images from data set

# %%
data_train_path = '../Fruits_Vegetables/train'
data_test_path = "../Fruits_Vegetables/test"
data_validate_path = "../Fruits_Vegetables/validation"

# %% [markdown]
# setting output path and model name

# %%
model_output_path = "../MLModels/"
model_name = "fruits_veg_model.keras"

# %% [markdown]
# Initializing image width and height

# %%
image_width = 180
image_height = 180

# %% [markdown]
# # Loading Data set from Directory Path

# %% [markdown]
# - reads images from folders
# - automatically assigns labels based on folder names
# - Resizes images to initialized image width and height
# - creates batches of size 32

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle = True,
    image_size = (image_width, image_height),
    batch_size = 32,
    validation_split =False
    )
# Out:
# Found 4377 files belonging to 98 classes.

# %%
data_category = data_train.class_names

# %% [markdown]
# Setting up validation data

# %%
data_validatation = tf.keras.utils.image_dataset_from_directory(
    data_validate_path,
    shuffle = True,
    image_size = (image_width, image_height),
    batch_size = 32,
    validation_split =False
    )
# Out:
# Found 351 files belonging to 36 classes.

# %% [markdown]
# setting up test data

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    shuffle = True,
    image_size = (image_width, image_height),
    batch_size = 32,
    validation_split =False
    )
# Out:
# Found 359 files belonging to 36 classes.

# %% [markdown]
# Plotting images from data set

# %%
plt.figure(figsize= (10,10))
for image,labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_category[labels[i]])
        plt.axis('off')

# %% [markdown]
# ## Building a CNN Model

# %% [markdown]
# - Conv layers extract image features
# - polling layers reduce size
# - flatten converts to vector
# - dense layers perform classification
# - Dropout prevents overfitting

# %%
model = Sequential([
    layers.Rescaling(1/255),
    layers.Conv2D(16,3,padding='same',activation= 'relu'),
    layers.MaxPool2D(),
    layers.Conv2D(32,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(units=len(data_category))
    ])

# %% [markdown]
# # Compiling the Model

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
    )
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# - model.fit() → this is the training step where the CNN actually learns patterns from your training images. Without this, your model is just an untrained network — it cannot classify anything.
#
# - data_train → your training images are passed here so the model can learn features of fruits/vegetables.
#
# - validation_data=data_validatation → used to evaluate model performance after each epoch. Helps detect overfitting.
#
# - epochs=epochs_size → number of full passes over your training dataset.
#
# - More epochs → better learning, but too many → overfitting.
#
# - batch_size=32 → number of images processed together in one step. Helps optimize memory usage.
#
# - verbose=1 → shows the progress of training in the console.
#
# - history → stores training metrics (accuracy & loss) for plotting and analysis.

# %%
epochs_size = 25
history = model.fit(
    data_train,
    validation_data=data_validatation,
    epochs=epochs_size,
    batch_size=32,
    verbose=1
    )
# Out:
# Epoch 1/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 19s 131ms/step - accuracy: 0.0880 - loss: 3.9356 - val_accuracy: 0.0142 - val_loss: 7.0612
# Epoch 2/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 107ms/step - accuracy: 0.3043 - loss: 2.6087 - val_accuracy: 0.0000e+00 - val_loss: 10.4316
# Epoch 3/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 107ms/step - accuracy: 0.5191 - loss: 1.7346 - val_accuracy: 0.0000e+00 - val_loss: 13.6016
# Epoch 4/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 109ms/step - accuracy: 0.6955 - loss: 1.0741 - val_accuracy: 0.0028 - val_loss: 14.9835
# Epoch 5/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 109ms/step - accuracy: 0.8280 - loss: 0.5952 - val_accuracy: 0.0000e+00 - val_loss: 18.8089
# Epoch 6/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 107ms/step - accuracy: 0.8942 - loss: 0.3665 - val_accuracy: 0.0000e+00 - val_loss: 20.7533
# Epoch 7/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 113ms/step - accuracy: 0.9173 - loss: 0.3053 - val_accuracy: 0.0000e+00 - val_loss: 22.2094
# Epoch 8/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 108ms/step - accuracy: 0.9388 - loss: 0.2104 - val_accuracy: 0.0000e+00 - val_loss: 22.0615
# Epoch 9/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 109ms/step - accuracy: 0.9497 - loss: 0.1902 - val_accuracy: 0.0000e+00 - val_loss: 25.3540
# Epoch 10/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 111ms/step - accuracy: 0.9671 - loss: 0.1474 - val_accuracy: 0.0000e+00 - val_loss: 23.3919
# Epoch 11/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 113ms/step - accuracy: 0.9753 - loss: 0.1164 - val_accuracy: 0.0000e+00 - val_loss: 25.8234
# Epoch 12/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 118ms/step - accuracy: 0.9762 - loss: 0.1172 - val_accuracy: 0.0000e+00 - val_loss: 24.5389
# Epoch 13/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 116ms/step - accuracy: 0.9760 - loss: 0.1189 - val_accuracy: 0.0000e+00 - val_loss: 23.8584
# Epoch 14/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 113ms/step - accuracy: 0.9760 - loss: 0.1110 - val_accuracy: 0.0000e+00 - val_loss: 24.6844
# Epoch 15/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 114ms/step - accuracy: 0.9817 - loss: 0.0793 - val_accuracy: 0.0000e+00 - val_loss: 24.9920
# Epoch 16/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 111ms/step - accuracy: 0.9806 - loss: 0.1051 - val_accuracy: 0.0000e+00 - val_loss: 26.0259
# Epoch 17/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 111ms/step - accuracy: 0.9817 - loss: 0.0854 - val_accuracy: 0.0000e+00 - val_loss: 27.4752
# Epoch 18/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 111ms/step - accuracy: 0.9829 - loss: 0.0744 - val_accuracy: 0.0000e+00 - val_loss: 25.9253
# Epoch 19/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 112ms/step - accuracy: 0.9783 - loss: 0.0859 - val_accuracy: 0.0000e+00 - val_loss: 27.5838
# Epoch 20/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 116ms/step - accuracy: 0.9804 - loss: 0.0849 - val_accuracy: 0.0000e+00 - val_loss: 26.2204
# Epoch 21/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 113ms/step - accuracy: 0.9774 - loss: 0.0916 - val_accuracy: 0.0000e+00 - val_loss: 27.7088
# Epoch 22/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 15s 111ms/step - accuracy: 0.9753 - loss: 0.0887 - val_accuracy: 0.0028 - val_loss: 25.1171
# Epoch 23/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 114ms/step - accuracy: 0.9666 - loss: 0.1210 - val_accuracy: 0.0028 - val_loss: 25.5654
# Epoch 24/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 113ms/step - accuracy: 0.9781 - loss: 0.0955 - val_accuracy: 0.0000e+00 - val_loss: 26.4291
# Epoch 25/25
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 16s 113ms/step - accuracy: 0.9836 - loss: 0.0690 - val_accuracy: 0.0000e+00 - val_loss: 24.7416

# %% [markdown]
# Plotting Accuracy and Val Accuracy

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label='TrainingAccuracy')
plt.plot(epochs_range,history.history['accuracy'],label='ValidationAccuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label='Trainingloss')
plt.plot(epochs_range,history.history['val_loss'],label='Validation loss')
plt.title('Loss')
plt.show()

# %% [markdown]
# ## saving the model

# %%
model.save(model_output_path+model_name)

# %% [markdown]
# ## Predicting a New Image

# %%
image = "hello.jpg"
image = tf.keras.utils.load_img(image,target_size=(image_height,image_width))
image_arr = tf.keras.utils.array_to_img(image)
image_bat = tf.expand_dims(image_arr,0)

# %%
predict = model.predict(image_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(
    data_category[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is carrot with accuracy of 98.52
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
