# %% [markdown]
# # Importing necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf


from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# Load images from data set

# %%
data_train_path = '../Fruits_Vegetables/train'
data_test_path = "../Fruits_Vegetables/test"
data_validate_path = "../Fruits_Vegetables/validation"

# %% [markdown]
# setting output path and model name

# %%
model_output_path = "../MLModels/"
model_name = "fruits_veg_model.keras"

# %% [markdown]
# Initializing image width and height

# %%
image_width = 180
image_height = 180

# %% [markdown]
# # Loading Data set from Directory Path

# %% [markdown]
# - reads images from folders
# - automatically assigns labels based on folder names
# - Resizes images to initialized image width and height
# - creates batches of size 32

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle = True,
    image_size = (image_width, image_height),
    batch_size = 32,
    validation_split =False
    )
# Out:
# Found 3115 files belonging to 36 classes.

# %%
data_category = data_train.class_names

# %% [markdown]
# Setting up validation data

# %%
data_validatation = tf.keras.utils.image_dataset_from_directory(
    data_validate_path,
    shuffle = True,
    image_size = (image_width, image_height),
    batch_size = 32,
    validation_split =False
    )
# Out:
# Found 351 files belonging to 36 classes.

# %% [markdown]
# setting up test data

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    shuffle = True,
    image_size = (image_width, image_height),
    batch_size = 32,
    validation_split =False
    )
# Out:
# Found 359 files belonging to 36 classes.

# %% [markdown]
# Plotting images from data set

# %%
plt.figure(figsize= (10,10))
for image,labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_category[labels[i]])
        plt.axis('off')

# %% [markdown]
# ## Building a CNN Model

# %% [markdown]
# - Conv layers extract image features
# - polling layers reduce size
# - flatten converts to vector
# - dense layers perform classification
# - Dropout prevents overfitting

# %%
model = Sequential([
    layers.Rescaling(1/255),
    layers.Conv2D(16,3,padding='same',activation= 'relu'),
    layers.MaxPool2D(),
    layers.Conv2D(32,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(units=len(data_category))
    ])

# %% [markdown]
# # Compiling the Model

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
    )

# %% [markdown]
# - model.fit() → this is the training step where the CNN actually learns patterns from your training images. Without this, your model is just an untrained network — it cannot classify anything.
#
# - data_train → your training images are passed here so the model can learn features of fruits/vegetables.
#
# - validation_data=data_validatation → used to evaluate model performance after each epoch. Helps detect overfitting.
#
# - epochs=epochs_size → number of full passes over your training dataset.
#
# - More epochs → better learning, but too many → overfitting.
#
# - batch_size=32 → number of images processed together in one step. Helps optimize memory usage.
#
# - verbose=1 → shows the progress of training in the console.
#
# - history → stores training metrics (accuracy & loss) for plotting and analysis.

# %%
epochs_size = 42
history = model.fit(
    data_train,
    validation_data=data_validatation,
    epochs=epochs_size,
    batch_size=32,
    verbose=1
    )
# Out:
# Epoch 1/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 27s 255ms/step - accuracy: 0.1037 - loss: 3.3321 - val_accuracy: 0.2991 - val_loss: 2.5190
# Epoch 2/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 25s 247ms/step - accuracy: 0.3210 - loss: 2.4295 - val_accuracy: 0.5185 - val_loss: 1.6388
# Epoch 3/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.4937 - loss: 1.7980 - val_accuracy: 0.7664 - val_loss: 0.9233
# Epoch 4/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━
42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 228ms/step - accuracy: 0.9791 - loss: 0.0806 - val_accuracy: 0.9459 - val_loss: 0.3812
# Epoch 27/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 226ms/step - accuracy: 0.9679 - loss: 0.1245 - val_accuracy: 0.9544 - val_loss: 0.2975
# Epoch 28/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 226ms/step - accuracy: 0.9711 - loss: 0.1122 - val_accuracy: 0.9402 - val_loss: 0.3289
# Epoch 29/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 224ms/step - accuracy: 0.9762 - loss: 0.0913 - val_accuracy: 0.9459 - val_loss: 0.3405
# Epoch 30/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 226ms/step - accuracy: 0.9762 - loss: 0.0948 - val_accuracy: 0.9573 - val_loss: 0.3269
# Epoch 31/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 226ms/step - accuracy: 0.9849 - loss: 0.0606 - val_accuracy: 0.9601 - val_loss: 0.3300
# Epoch 32/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 225ms/step - accuracy: 0.9868 - loss: 0.0513 - val_accuracy: 0.9487 - val_loss: 0.4000
# Epoch 33/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 225ms/step - accuracy: 0.9884 - loss: 0.0497 - val_accuracy: 0.9630 - val_loss: 0.3653
# Epoch 34/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 241ms/step - accuracy: 0.9897 - loss: 0.0374 - val_accuracy: 0.9630 - val_loss: 0.3691
# Epoch 35/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 227ms/step - accuracy: 0.9891 - loss: 0.0438 - val_accuracy: 0.9601 - val_loss: 0.3400
# Epoch 36/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 226ms/step - accuracy: 0.9910 - loss: 0.0361 - val_accuracy: 0.9601 - val_loss: 0.3564
# Epoch 37/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 223ms/step - accuracy: 0.9920 - loss: 0.0334 - val_accuracy: 0.9630 - val_loss: 0.3358
# Epoch 38/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 236ms/step - accuracy: 0.9904 - loss: 0.0363 - val_accuracy: 0.9630 - val_loss: 0.3044
# Epoch 39/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 228ms/step - accuracy: 0.9917 - loss: 0.0296 - val_accuracy: 0.9601 - val_loss: 0.3475
# Epoch 40/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 25s 254ms/step - accuracy: 0.9897 - loss: 0.0298 - val_accuracy: 0.9601 - val_loss: 0.3484
# Epoch 41/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 242ms/step - accuracy: 0.9910 - loss: 0.0318 - val_accuracy: 0.9573 - val_loss: 0.3550
# Epoch 42/42
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 244ms/step - accuracy: 0.9920 - loss: 0.0282 - val_accuracy: 0.9544 - val_loss: 0.3487

# %% [markdown]
# Plotting Accuracy and Val Accuracy

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label='TrainingAccuracy')
plt.plot(epochs_range,history.history['accuracy'],label='ValidationAccuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label='Trainingloss')
plt.plot(epochs_range,history.history['val_loss'],label='Validation loss')
plt.title('Loss')
plt.show()

# %% [markdown]
# ## saving the model

# %%
# model.save(model_output_path+model_name)

# %% [markdown]
# ## Predicting a New Image

# %%
image = "banana1.jpg"
image = tf.keras.utils.load_img(image,target_size=(image_height,image_width))
image_arr = tf.keras.utils.array_to_img(image)
image_bat = tf.expand_dims(image_arr,0)

# %%
predict = model.predict(image_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(
    data_category[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is sweetcorn with accuracy of 79.44
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
